# %% [markdown]
# # <span style="color:red">++++++++++++++++++++++Ayad++++++++++++++++++++++</span>

# %% [markdown]
# # <span style="color:blue">1- Data</span>

# %%
import pandas as pd

# %%
data = pd.read_csv(r'D:\Projects\Machine Learning\Unsupervised Learning\data.csv')
data.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -2.084839 -0.471673 -0.955542 -0.567288 -0.953226 -1.510386  0.921728
# 1  0.003700 -0.999118  0.202003  1.612001 -0.375642  0.378518  0.113693
# 2 -1.456240  0.483522 -0.508605 -0.316406 -1.695560 -1.943310  0.299486
# 3 -1.595524 -0.219744  1.039403  0.381587  0.109094 -0.155068  0.156054
# 4  0.995277 -1.517259 -0.101198  1.415742 -0.054356  0.611216  0.196938
#
#           7
# 0  0.437954
# 1  1.718011
# 2  0.147370
# 3  0.007314
# 4  0.641809

# %%
data.shape
# Out:
# (1309, 8)

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
plt.scatter(data.iloc[:, 0].values, data.iloc[:, 1].values, c = 'm', alpha=0.8)
plt.show()

# %% [markdown]
# # <span style="color:blue">2- Dendrogram</span>

# %%
from scipy.cluster.hierarchy import dendrogram, ward

# %%
linkage_matrix = ward(data)
linkage_matrix.shape
# Out:
# (1308, 4)

# %%
import matplotlib.pyplot as plt

plt.style.use('dark_background')

# %%
plt.figure(figsize=(15, 15))

dendrogram(linkage_matrix)
plt.show()

# %% [markdown]
# # <span style="color:blue">3- Agglomerative Technique</span>

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
ward = AgglomerativeClustering(n_clusters = 3)
ward_labels = Agg.fit_predict(data)

# %%
complete = AgglomerativeClustering(n_clusters = 3, linkage='complete')
complete_labels = Agg.fit_predict(data)

# %%
avg = AgglomerativeClustering(n_clusters = 3, linkage='average')
avg_labels = Agg.fit_predict(data)

# %%
from sklearn.metrics import silhouette_score

# %%
ward_score = silhouette_score(data, ward_labels)
complete_score = silhouette_score(data, complete_labels)
avg_score = silhouette_score(data, avg_labels)

# %%
print( "Scores: \nWard:", ward_score,"\nComplete: ", complete_score, "\nAverage: ", avg_score)
# Out:
# Scores:
# Ward: 0.3117324288325592
# Complete:  0.3117324288325592
# Average:  0.3117324288325592

# %% [markdown]
# # <span style="color:blue">4- Concatenate the labels with the data</span>

# %%
df = pd.DataFrame(ward_labels, columns = ['Labels'])
df
# Out:
#       Labels
# 0          1
# 1          0
# 2          1
# 3          1
# 4          0
# ...      ...
# 1304       0
# 1305       2
# 1306       0
# 1307       2
# 1308       1
#
# [1309 rows x 1 columns]

# %%
pd.concat([data, df], axis=1)
# Out:
#              0         1         2         3         4         5         6  \
# 0    -2.084839 -0.471673 -0.955542 -0.567288 -0.953226 -1.510386  0.921728
# 1     0.003700 -0.999118  0.202003  1.612001 -0.375642  0.378518  0.113693
# 2    -1.456240  0.483522 -0.508605 -0.316406 -1.695560 -1.943310  0.299486
# 3    -1.595524 -0.219744  1.039403  0.381587  0.109094 -0.155068  0.156054
# 4     0.995277 -1.517259 -0.101198  1.415742 -0.054356  0.611216  0.196938
# ...        ...       ...       ...       ...       ...       ...       ...
# 1304 -0.862703  0.104828  1.984113 -2.026618 -1.723234  1.355618  0.019176
# 1305  0.299519  2.404711 -0.473917  0.539437  0.144996  1.079460 -0.593131
# 1306  1.983708 -2.251345 -0.891493  0.934429  0.553115  1.194912  0.344667
# 1307  0.369343  3.529447 -0.542355 -1.130391  0.468369 -0.998843  0.550265
# 1308 -2.118941 -0.456731 -1.179383 -0.667595 -1.091675 -1.680951  0.895348
#
#              7  Labels
# 0     0.437954       1
# ...

# %% [markdown]
# # <span style="color:red">++++++++++++++++++++++Ayad++++++++++++++++++++++</span>
